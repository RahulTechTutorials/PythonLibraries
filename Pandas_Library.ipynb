# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulTechTutorials/PythonLibraries/blob/master/Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Library
#
# ```
# # This is formatted as code
# ```

# %%
import pandas as ps
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/sample_data/")

# %%
os.listdir()
# Out:
# ['anscombe.json',
#  'README.md',
#  'nyc_weather.csv',
#  'mnist_train_small.csv',
#  'california_housing_train.csv',
#  'mnist_test.csv',
#  'california_housing_test.csv']

# %%
df = ps.read_csv('nyc_weather.csv')

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
##Maximum Temperature
df['Temperature'].max()
# Out:
# 50

# %%
##Dates when it rained
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
## Average Wind speed
df['WindSpeedMPH'].mean()
# Out:
# np.float64(6.892857142857143)

# %%
df.fillna(0, inplace=True)

# %%
df['WindSpeedMPH'].mean()
# Out:
# np.float64(6.225806451612903)

# %%
columns = ['day', 'temperature', 'windspeed', 'event' ]
days = []
df = pd.Dataframe(data, column = columns)

# %%
import pandas as pd
data = [
    {"date": "1/1/2017", "temperature": 32, "windspeed": 6, "event": "Rain"},
    {"date": "1/2/2017", "temperature": 35, "windspeed": 7, "event": "Sunny"},
    {"date": "1/3/2017", "temperature": 28, "windspeed": 2, "event": "Snow"},
    {"date": "1/4/2017", "temperature": 24, "windspeed": 7, "event": "Snow"},
    {"date": "1/5/2017", "temperature": 32, "windspeed": 4, "event": "Rain"},
    {"date": "1/6/2017", "temperature": 32, "windspeed": 2, "event": "Sunny"},
]

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' column to datetime type (optional but recommended)
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#         date  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow
# 3 2017-01-04           24          7   Snow
# 4 2017-01-05           32          4   Rain
# 5 2017-01-06           32          2  Sunny

# %%
df.head()
# Out:
#         date  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow
# 3 2017-01-04           24          7   Snow
# 4 2017-01-05           32          4   Rain

# %%
## gives the shape of the data frame i.e. number of cols and rows
df.shape
# Out:
# (6, 4)

# %%
df.head(1)
# Out:
#         date  temperature  windspeed event
# 0 2017-01-01           32          6  Rain

# %%
df.tail(1)
# Out:
#         date  temperature  windspeed  event
# 5 2017-01-06           32          2  Sunny

# %%
df[2:5]
# Out:
#         date  temperature  windspeed event
# 2 2017-01-03           28          2  Snow
# 3 2017-01-04           24          7  Snow
# 4 2017-01-05           32          4  Rain

# %%
df['date']
# Out:
# 0   2017-01-01
# 1   2017-01-02
# 2   2017-01-03
# 3   2017-01-04
# 4   2017-01-05
# 5   2017-01-06
# Name: date, dtype: datetime64[ns]

# %%
df.columns[:]
df.columns.to_list()
# Out:
# ['date', 'temperature', 'windspeed', 'event']

# %%
print(type(df['event']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[['date','temperature','windspeed']]
# Out:
#         date  temperature  windspeed
# 0 2017-01-01           32          6
# 1 2017-01-02           35          7
# 2 2017-01-03           28          2
# 3 2017-01-04           24          7
# 4 2017-01-05           32          4
# 5 2017-01-06           32          2

# %%
df['temperature'].max()
df['temperature'].mean()
df['temperature'].median()
# Out:
# 32.0

# %%
df.describe()
# Out:
#                       date  temperature  windspeed
# count                    6     6.000000   6.000000
# mean   2017-01-03 12:00:00    30.500000   4.666667
# min    2017-01-01 00:00:00    24.000000   2.000000
# 25%    2017-01-02 06:00:00    29.000000   2.500000
# 50%    2017-01-03 12:00:00    32.000000   5.000000
# 75%    2017-01-04 18:00:00    32.000000   6.750000
# max    2017-01-06 00:00:00    35.000000   7.000000
# std                    NaN     3.885872   2.338090

# %%
df[df['temperature'] > 32]
df[df.temperature > 32]
# Out:
#         date  temperature  windspeed  event
# 1 2017-01-02           35          7  Sunny

# %%
df[df.temperature == df.temperature.max()]
# Out:
#         date  temperature  windspeed  event
# 1 2017-01-02           35          7  Sunny

# %%
df[['date','temperature']][df.temperature == df.temperature.max()]
# Out:
#         date  temperature
# 1 2017-01-02           35

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('date',inplace=True)

# %%
df.loc['2017-01-01']
# Out:
# temperature      32
# windspeed         6
# event          Rain
# Name: 2017-01-01 00:00:00, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#         date  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow
# 3 2017-01-04           24          7   Snow
# 4 2017-01-05           32          4   Rain
# 5 2017-01-06           32          2  Sunny

# %%
df.set_index('event',inplace=True)

# %%
df
# Out:
#             date  temperature  windspeed
# event
# Rain  2017-01-01           32          6
# Sunny 2017-01-02           35          7
# Snow  2017-01-03           28          2
# Snow  2017-01-04           24          7
# Rain  2017-01-05           32          4
# Sunny 2017-01-06           32          2

# %%
df.loc['Snow']
# Out:
#             date  temperature  windspeed
# event
# Snow  2017-01-03           28          2
# Snow  2017-01-04           24          7

# %%
import pandas as pd
data = [{'day': '1/1/2017','temperature': 32, 'windspeed':6, 'event':'Rain'},
 {'day': '1/2/2017','temperature': 35, 'windspeed':7, 'event':'Sunny'},
  {'day': '1/3/2017','temperature': 28, 'windspeed':2, 'event':'Snow'}]

# %%
df = pd.DataFrame(data)

# %%
df.day = pd.to_datetime(df.day)

# %%
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
import pandas as pd
weather_data = [('1/1/2017', 32,6, 'Rain'),
 ( '1/2/2017',35, 7, 'Sunny'),
  ('1/3/2017',28, 2, 'Snow')
]


columns = ['day','temperature','windspeed','event' ]
df= pd.DataFrame(weather_data, columns = columns)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.to_csv('write_csv.csv')

# %%
os.listdir()
# Out:
# ['anscombe.json',
#  'README.md',
#  'write_csv.csv',
#  'nyc_weather.csv',
#  'mnist_train_small.csv',
#  'california_housing_train.csv',
#  'mnist_test.csv',
#  'california_housing_test.csv']

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %% [markdown]
# # Handling Missing data in Pandas

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"date": "1/1/2017", "temperature": 32, "windspeed": None, "event": "Rain"},
    {"date": "1/4/2017", "temperature": None, "windspeed": None, "event": "Sunny"},
    {"date": "1/5/2017", "temperature": 28, "windspeed": None, "event": "Snow"},
    {"date": "1/6/2017", "temperature": None, "windspeed": 7, "event": None},
    {"date": "1/7/2017", "temperature": 32, "windspeed": None, "event": "Rain"},
    {"date": "1/8/2017", "temperature": None, "windspeed": None, "event": "Sunny"},
    {"date": "1/9/2017", "temperature": 34, "windspeed": None, "event": "Cloudy"},
    {"date": "1/11/2017", "temperature": 40, "windspeed": 12, "event": None},
]

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' to datetime
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#         date  temperature  windspeed   event
# 0 2017-01-01         32.0        NaN    Rain
# 1 2017-01-04          NaN        NaN   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0    None
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09         34.0        NaN  Cloudy
# 7 2017-01-11         40.0       12.0    None

# %%
df
# Out:
#         date  temperature  windspeed   event
# 0 2017-01-01         32.0        NaN    Rain
# 1 2017-01-04          NaN        NaN   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0    None
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09         34.0        NaN  Cloudy
# 7 2017-01-11         40.0       12.0    None

# %%
print(type(df.date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.date = pd.to_datetime(df.date)

# %%
df.set_index('date',inplace=True)

# %%
df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
##new_df = df.fillna(0)
new_df = df.fillna({
    'temperature' : 0,
    'windspeed' : 0,
    'event' : 'No event'
}
)

# %%
new_df = df.fillna(method = 'bfill').fillna(method='ffill')
# Out:
# /tmp/ipykernel_24573/4107334947.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = 'bfill').fillna(method='ffill')

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        7.0    Rain
# 2017-01-04         28.0        7.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0       12.0    Rain
# 2017-01-08         34.0       12.0   Sunny
# 2017-01-09         34.0       12.0  Cloudy
# 2017-01-11         40.0       12.0  Cloudy

# %%
new_df = df.fillna(method = 'bfill', axis="columns") ## copy the values horizontally
# Out:
# /tmp/ipykernel_24573/989468544.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = 'bfill', axis="columns")
# /tmp/ipykernel_24573/989468544.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df = df.fillna(method = 'bfill', axis="columns")

# %%
new_df = df.fillna(method = 'bfill').fillna(method='ffill')
# Out:
# /tmp/ipykernel_24573/4107334947.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method = 'bfill').fillna(method='ffill')

# %%
df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
 ##Linear interpolation

new_df = df.interpolate(method = 'time')
# Out:
# /tmp/ipykernel_24573/1625167598.py:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method = 'time')

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04         29.0        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06         30.0        7.0    None
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         33.0        9.0   Sunny
# 2017-01-09         34.0       10.0  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
new_df = df.dropna(how='all')

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
new_df = df.dropna(thresh=1) ##Need atleast one valid value to stay

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
date_range = pd.date_range('2017-01-01','2017-01-11')
date_range
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
idx = pd.DatetimeIndex(date_range)

# %%
idx
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11'],
#               dtype='datetime64[ns]', freq='D')

# %%
new_df.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        NaN    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-10          NaN        NaN     NaN
# 2017-01-11         40.0       12.0    None

# %%
df[df.temperature.isna()]
# Out:
#             temperature  windspeed  event
# date
# 2017-01-04          NaN        NaN  Sunny
# 2017-01-06          NaN        7.0   None
# 2017-01-08          NaN        NaN  Sunny

# %%
import numpy as np
new_df = df.replace('None' ,np.nan)

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
##replace values by column

new_df.replace({
    "temperature" : -9999,
    "windspeed"   : -9999,
    "event"       : '0'
}, np.nan)
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
new_df = df.replace({
    -9999 : np.nan,
    'No event' : 'Sunny'
})

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
new_df = df.replace({
    'temperature' : 'A-Za-z',
    'windspeed' : 'A-Za-z'
},'', regex=True)

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %%
## 1-1 replacement values
new_df = df.replace(['rob','maya','rahul'],[1,2,3])

# %%
new_df
# Out:
#             temperature  windspeed   event
# date
# 2017-01-01         32.0        NaN    Rain
# 2017-01-04          NaN        NaN   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0    None
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        NaN  Cloudy
# 2017-01-11         40.0       12.0    None

# %% [markdown]
# # Group by

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"date": "1/1/2017", "city": "new york", "temperature": 32, "windspeed": 6, "event": "Rain"},
    {"date": "1/2/2017", "city": "new york", "temperature": 36, "windspeed": 7, "event": "Sunny"},
    {"date": "1/3/2017", "city": "new york", "temperature": 28, "windspeed": 5, "event": "Snow"},
    {"date": "1/4/2017", "city": "new york", "temperature": 33, "windspeed": 7, "event": "Sunny"},
    {"date": "1/1/2017", "city": "mumbai", "temperature": 90, "windspeed": 5, "event": "Sunny"},
    {"date": "1/2/2017", "city": "mumbai", "temperature": 85, "windspeed": 12, "event": "Fog"},
    {"date": "1/3/2017", "city": "mumbai", "temperature": 87, "windspeed": 15, "event": "Fog"},
    {"date": "1/4/2017", "city": "mumbai", "temperature": 92, "windspeed": 5, "event": "Rain"},
    {"date": "1/1/2017", "city": "paris", "temperature": 45, "windspeed": 10, "event": "Sunny"},
    {"date": "1/2/2017", "city": "paris", "temperature": 50, "windspeed": 13, "event": "Cloudy"},
    {"date": "1/3/2017", "city": "paris", "temperature": 54, "windspeed": 8, "event": "Cloudy"},
    {"date": "1/4/2017", "city": "paris", "temperature": 42, "windspeed": 10, "event": "Cloudy"}
]

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#          date      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28          5    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         10   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
df
# Out:
#          date      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28          5    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         10   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#          date      city  temperature  windspeed   event
# 0  2017-01-01  new york           32          6    Rain
# 1  2017-01-02  new york           36          7   Sunny
# 2  2017-01-03  new york           28          5    Snow
# 3  2017-01-04  new york           33          7   Sunny
# 4  2017-01-01    mumbai           90          5   Sunny
# 5  2017-01-02    mumbai           85         12     Fog
# 6  2017-01-03    mumbai           87         15     Fog
# 7  2017-01-04    mumbai           92          5    Rain
# 8  2017-01-01     paris           45         10   Sunny
# 9  2017-01-02     paris           50         13  Cloudy
# 10 2017-01-03     paris           54          8  Cloudy
# 11 2017-01-04     paris           42         10  Cloudy

# %%
new_df = df.groupby('city')

# %%
for city, city_df in new_df:
  print(city,city_df)
# Out:
# mumbai         date    city  temperature  windspeed  event
# 4 2017-01-01  mumbai           90          5  Sunny
# 5 2017-01-02  mumbai           85         12    Fog
# 6 2017-01-03  mumbai           87         15    Fog
# 7 2017-01-04  mumbai           92          5   Rain
# new york         date      city  temperature  windspeed  event
# 0 2017-01-01  new york           32          6   Rain
# 1 2017-01-02  new york           36          7  Sunny
# 2 2017-01-03  new york           28          5   Snow
# 3 2017-01-04  new york           33          7  Sunny
# paris          date   city  temperature  windspeed   event
# 8  2017-01-01  paris           45         10   Sunny
# 9  2017-01-02  paris           50         13  Cloudy
# 10 2017-01-03  paris           54          8  Cloudy
# 11 2017-01-04  paris           42         10  Cloudy

# %%
new_df.get_group('new york')
# Out:
#         date      city  temperature  windspeed  event
# 0 2017-01-01  new york           32          6   Rain
# 1 2017-01-02  new york           36          7  Sunny
# 2 2017-01-03  new york           28          5   Snow
# 3 2017-01-04  new york           33          7  Sunny

# %%
new_df.max()
# Out:
#                date  temperature  windspeed  event
# city
# mumbai   2017-01-04           92         15  Sunny
# new york 2017-01-04           36          7  Sunny
# paris    2017-01-04           54         13  Sunny

# %%
new_df.describe()
# Out:
#           date                                                                 \
#          count                 mean                  min                  25%
# city
# mumbai       4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# new york     4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
# paris        4  2017-01-02 12:00:00  2017-01-01 00:00:00  2017-01-01 18:00:00
#
#                                                                               \
#                           50%                  75%                  max  std
# city
# mumbai    2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# new york  2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
# paris     2017-01-02 12:00:00  2017-01-03 06:00:00  2017-01-04 00:00:00  NaN
#
#          temperature         ...                 windspeed                    \
#                count   mean  ...   max       std     count   mean  min   25%
# ...

# %%
# %matplotlib inline
new_df.plot()
# Out:
# city
# mumbai      Axes(0.125,0.11;0.775x0.77)
# new york    Axes(0.125,0.11;0.775x0.77)
# paris       Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# # Concat

# %%
import pandas as pd
india_weather = {
    "city" : ["mumbai","delhi","bangalore"],
    "temperature" : [32,45,30],
    "humidity" : [80,60,78]
}

us_weather = {
    "city" : ["new york","chicago","orlando"],
    "temperature" : [21,14,35],
    "humidity" : [68,65,75]
}

# %%
df_india = pd.DataFrame(india_weather)
df_us = pd.DataFrame(us_weather)

# %%
df_india
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78

# %%
pd.concat([df_india, df_us], ignore_index=True)
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 3   new york           21        68
# 4    chicago           14        65
# 5    orlando           35        75

# %%
new_df = pd.concat([df_india, df_us], keys=['india','us'])

# %%
new_df
# Out:
#               city  temperature  humidity
# india 0     mumbai           32        80
#       1      delhi           45        60
#       2  bangalore           30        78
# us    0   new york           21        68
#       1    chicago           14        65
#       2    orlando           35        75

# %%
new_df.loc['india']
# Out:
#         city  temperature  humidity
# 0     mumbai           32        80
# 1      delhi           45        60
# 2  bangalore           30        78

# %%
temperature_df = pd.DataFrame({
    "city" : ["delhi","mumbai","bangalore"],
    "temperature" : [32,45,30]
},index=[2,1,3])

# %%
temperature_df
# Out:
#         city  temperature
# 0     mumbai           32
# 1      delhi           45
# 2  bangalore           30

# %%
windspeed_df = pd.DataFrame({
    "city" : ["mumbai","delhi","bangalore"],
    "windspeed" : [7,12,9]
}, index=[1,2,3])

# %%
windspeed_df
# Out:
#         city  windspeed
# 0     mumbai          7
# 1      delhi         12
# 2  bangalore          9

# %%
pd.concat([temperature_df,windspeed_df],axis = 1)
# Out:
#         city  temperature       city  windspeed
# 2      delhi           32      delhi         12
# 1     mumbai           45     mumbai          7
# 3  bangalore           30  bangalore          9

# %%
##add a series to the dataframe

s = pd.Series(['Humid','Dry','Rain'], name='event',index=[1,2,3])

# %%
new_df = pd.concat([temperature_df,s], axis=1)

# %%
new_df
# Out:
#         city  temperature  event
# 2      delhi           32    Dry
# 1     mumbai           45  Humid
# 3  bangalore           30   Rain

# %% [markdown]
# # Merge

# %%
pd.merge(temperature_df, windspeed_df, on='city')
# Out:
#         city  temperature  windspeed
# 0      delhi           32         12
# 1     mumbai           45          7
# 2  bangalore           30          9

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city" : ["new york","chicago","orlando","baltimore"],
    "temperature" : [21,14,35,32]
})

df2 = pd.DataFrame({
    "city" : ["chicago","new york","orlando","san francisco"],
    "humidity" : [65,68,75,100]
})

# %%
pd.merge(df1,df2, on='city',how="outer",indicator = True)
# Out:
#             city  temperature  humidity      _merge
# 0      baltimore         32.0       NaN   left_only
# 1        chicago         14.0      65.0        both
# 2       new york         21.0      68.0        both
# 3        orlando         35.0      75.0        both
# 4  san francisco          NaN     100.0  right_only

# %% [markdown]
# # Pivot

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"date": "5/1/2017", "city": "new york", "temperature": 65, "humidity": 56},
    {"date": "5/2/2017", "city": "new york", "temperature": 66, "humidity": 58},
    {"date": "5/3/2017", "city": "new york", "temperature": 68, "humidity": 60},
    {"date": "5/1/2017", "city": "mumbai", "temperature": 75, "humidity": 80},
    {"date": "5/2/2017", "city": "mumbai", "temperature": 78, "humidity": 83},
    {"date": "5/3/2017", "city": "mumbai", "temperature": 82, "humidity": 85},
    {"date": "5/1/2017", "city": "beijing", "temperature": 80, "humidity": 26},
    {"date": "5/2/2017", "city": "beijing", "temperature": 77, "humidity": 30},
    {"date": "5/3/2017", "city": "beijing", "temperature": 79, "humidity": 35}
]

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           66        58
# 2 2017-05-03  new york           68        60
# 3 2017-05-01    mumbai           75        80
# 4 2017-05-02    mumbai           78        83
# 5 2017-05-03    mumbai           82        85
# 6 2017-05-01   beijing           80        26
# 7 2017-05-02   beijing           77        30
# 8 2017-05-03   beijing           79        35

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           66        58
# 2 2017-05-03  new york           68        60
# 3 2017-05-01    mumbai           75        80
# 4 2017-05-02    mumbai           78        83
# 5 2017-05-03    mumbai           82        85
# 6 2017-05-01   beijing           80        26
# 7 2017-05-02   beijing           77        30
# 8 2017-05-03   beijing           79        35

# %%
df.pivot(index="date",columns="city",values = "humidity")
# Out:
# city        beijing  mumbai  new york
# date
# 2017-05-01       26      80        56
# 2017-05-02       30      83        58
# 2017-05-03       35      85        60

# %% [markdown]
# # Pivot Table

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"date": "5/1/2017", "city": "new york", "temperature": 65, "humidity": 56},
    {"date": "5/2/2017", "city": "new york", "temperature": 66, "humidity": 58},
    {"date": "5/3/2017", "city": "new york", "temperature": 68, "humidity": 60},
    {"date": "5/1/2017", "city": "mumbai", "temperature": 75, "humidity": 80},
    {"date": "5/2/2017", "city": "mumbai", "temperature": 78, "humidity": 83},
    {"date": "5/3/2017", "city": "mumbai", "temperature": 82, "humidity": 85},
    {"date": "5/1/2017", "city": "beijing", "temperature": 80, "humidity": 26},
    {"date": "5/2/2017", "city": "beijing", "temperature": 77, "humidity": 30},
    {"date": "5/3/2017", "city": "beijing", "temperature": 79, "humidity": 35}
]

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' column to datetime
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           66        58
# 2 2017-05-03  new york           68        60
# 3 2017-05-01    mumbai           75        80
# 4 2017-05-02    mumbai           78        83
# 5 2017-05-03    mumbai           82        85
# 6 2017-05-01   beijing           80        26
# 7 2017-05-02   beijing           77        30
# 8 2017-05-03   beijing           79        35

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           66        58
# 2 2017-05-03  new york           68        60
# 3 2017-05-01    mumbai           75        80
# 4 2017-05-02    mumbai           78        83
# 5 2017-05-03    mumbai           82        85
# 6 2017-05-01   beijing           80        26
# 7 2017-05-02   beijing           77        30
# 8 2017-05-03   beijing           79        35

# %%
df.pivot_table(index="city",columns="date",aggfunc="sum")
# Out:
#            humidity                       temperature
# date     2017-05-01 2017-05-02 2017-05-03  2017-05-01 2017-05-02 2017-05-03
# city
# beijing          26         30         35          80         77         79
# mumbai           80         83         85          75         78         82
# new york         56         58         60          65         66         68

# %%
df.pivot_table(index='city',columns='date',margins=True )
# Out:
#                     humidity                                          \
# date     2017-05-01 00:00:00 2017-05-02 00:00:00 2017-05-03 00:00:00
# city
# beijing                 26.0                30.0                35.0
# mumbai                  80.0                83.0                85.0
# new york                56.0                58.0                60.0
# All                     54.0                57.0                60.0
#
#                             temperature                      \
# date            All 2017-05-01 00:00:00 2017-05-02 00:00:00
# city
# beijing   30.333333           80.000000           77.000000
# mumbai    82.666667           75.000000           78.000000
# new york  58.000000           65.000000           66.000000
# All       57.000000           73.333333           73.666667
#
#
# date     2017-05-03 00:00:00        All
# city
# beijing            79.000000  78.666667
# mumbai             82.000000  78.333333
# new york           68.000000  66.333333
# ...

# %%
import pandas as pd

# Define the data
data = {
    'date': ['5/1/2017', '5/2/2017', '5/3/2017', '12/1/2017', '12/2/2017', '5/12/2017'],
    'city': ['new york'] * 6,
    'temperature': [65, 61, 70, 30, 28, 25],
    'humidity': [56, 54, 60, 50, 52, 51]
}

# Create DataFrame
df = pd.DataFrame(data)

# Convert 'date' to datetime
df['date'] = pd.to_datetime(df['date'])

# Display the DataFrame
print(df)
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-05-12  new york           25        51

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-05-12  new york           25        51

# %%
df.groupby(['city']).mean()
# Out:
#                         date  temperature   humidity
# city
# new york 2017-07-13 20:00:00         46.5  53.833333

# %%
df.groupby(pd.Grouper(key="city")).mean()
# Out:
#                         date  temperature   humidity
# city
# new york 2017-07-13 20:00:00         46.5  53.833333

# %%
df.groupby(["city"]).mean()
# Out:
#                         date  temperature   humidity
# city
# new york 2017-07-13 20:00:00         46.5  53.833333

# %%
df.groupby(pd.Grouper(key="city")).mean()
# Out:
#                         date  temperature   humidity
# city
# new york 2017-07-13 20:00:00         46.5  53.833333

# %%
df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-05-12  new york           25        51

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'), columns = 'city')
# Out:
# /tmp/ipykernel_2310/1681347133.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.pivot_table(index=pd.Grouper(freq='M',key='date'), columns = 'city')
#            humidity temperature
# city       new york    new york
# date
# 2017-05-31    55.25       55.25
# 2017-12-31    51.00       29.00

# %%
from datetime import datetime

date_string = "2026-10-25"

datetime.strptime(date_string,"%Y-%m-%d").month
# Out:
# 10

# %% [markdown]
# # Melt

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"day": "Monday", "chicago": 32, "chennai": 75, "berlin": 41},
    {"day": "Tuesday", "chicago": 30, "chennai": 77, "berlin": 43},
    {"day": "Wednesday", "chicago": 28, "chennai": 75, "berlin": 45},
    {"day": "Thursday", "chicago": 22, "chennai": 82, "berlin": 38},
    {"day": "Friday", "chicago": 30, "chennai": 83, "berlin": 30},
    {"day": "Saturday", "chicago": 20, "chennai": 81, "berlin": 45},
    {"day": "Sunday", "chicago": 25, "chennai": 77, "berlin": 47}
]

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
pd.melt(df, id_vars='day', value_vars= ['chicago','chennai','berlin'],var_name= 'city',value_name = 'temperature')
# Out:
#           day     city  temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %%
##. unpivot this to day, city, temperature
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame: 'DataFrame', id_vars=None, value_vars=None, var_name=None, value_name: 'Hashable' = 'value', col_level=None, ignore_index: 'bool' = True) -> 'DataFrame'
#     Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#     Parameters
#     ----------
#     id_vars : scalar, tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : scalar, tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar, default None
# ...

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"Company": "2017-06-05", "Facebook_Price": 155, "Google_Price": 955, "Microsoft_Price": 66,
     "Facebook_PE": 37.10, "Google_PE": 32.0, "Microsoft_PE": 30.31},
    {"Company": "2017-06-06", "Facebook_Price": 150, "Google_Price": 987, "Microsoft_Price": 69,
     "Facebook_PE": 36.98, "Google_PE": 31.3, "Microsoft_PE": 30.56},
    {"Company": "2017-06-07", "Facebook_Price": 153, "Google_Price": 963, "Microsoft_Price": 62,
     "Facebook_PE": 36.78, "Google_PE": 31.7, "Microsoft_PE": 30.46},
    {"Company": "2017-06-08", "Facebook_Price": 155, "Google_Price": 1000, "Microsoft_Price": 61,
     "Facebook_PE": 36.11, "Google_PE": 31.2, "Microsoft_PE": 30.11},
    {"Company": "2017-06-09", "Facebook_Price": 156, "Google_Price": 1012, "Microsoft_Price": 66,
     "Facebook_PE": 37.07, "Google_PE": 30.0, "Microsoft_PE": 31.00}
]

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       Company  Facebook_Price  Google_Price  Microsoft_Price  Facebook_PE  \
# 0  2017-06-05             155           955               66        37.10
# 1  2017-06-06             150           987               69        36.98
# 2  2017-06-07             153           963               62        36.78
# 3  2017-06-08             155          1000               61        36.11
# 4  2017-06-09             156          1012               66        37.07
#
#    Google_PE  Microsoft_PE
# 0       32.0         30.31
# 1       31.3         30.56
# 2       31.7         30.46
# 3       31.2         30.11
# 4       30.0         31.00

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"Date": "2017-06-05", "Facebook_Price": 155, "Google_Price": 955, "Microsoft_Price": 66,
     "Facebook_PE": 37.10, "Google_PE": 32.0, "Microsoft_PE": 30.31},
    {"Date": "2017-06-06", "Facebook_Price": 150, "Google_Price": 987, "Microsoft_Price": 69,
     "Facebook_PE": 36.98, "Google_PE": 31.3, "Microsoft_PE": 30.56},
    {"Date": "2017-06-07", "Facebook_Price": 153, "Google_Price": 963, "Microsoft_Price": 62,
     "Facebook_PE": 36.78, "Google_PE": 31.7, "Microsoft_PE": 30.46},
    {"Date": "2017-06-08", "Facebook_Price": 155, "Google_Price": 1000, "Microsoft_Price": 61,
     "Facebook_PE": 36.11, "Google_PE": 31.2, "Microsoft_PE": 30.11},
    {"Date": "2017-06-09", "Facebook_Price": 156, "Google_Price": 1012, "Microsoft_Price": 66,
     "Facebook_PE": 37.07, "Google_PE": 30.0, "Microsoft_PE": 31.00}
]

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date  Facebook_Price  Google_Price  Microsoft_Price  Facebook_PE  \
# 0  2017-06-05             155           955               66        37.10
# 1  2017-06-06             150           987               69        36.98
# 2  2017-06-07             153           963               62        36.78
# 3  2017-06-08             155          1000               61        36.11
# 4  2017-06-09             156          1012               66        37.07
#
#    Google_PE  Microsoft_PE
# 0       32.0         30.31
# 1       31.3         30.56
# 2       31.7         30.46
# 3       31.2         30.11
# 4       30.0         31.00

# %%
df.stack()
# Out:
# 0  Date               2017-06-05
#    Facebook_Price            155
#    Google_Price              955
#    Microsoft_Price            66
#    Facebook_PE              37.1
#    Google_PE                32.0
#    Microsoft_PE            30.31
# 1  Date               2017-06-06
#    Facebook_Price            150
#    Google_Price              987
#    Microsoft_Price            69
#    Facebook_PE             36.98
#    Google_PE                31.3
#    Microsoft_PE            30.56
# 2  Date               2017-06-07
#    Facebook_Price            153
#    Google_Price              963
#    Microsoft_Price            62
#    Facebook_PE             36.78
#    Google_PE                31.7
#    Microsoft_PE            30.46
# 3  Date               2017-06-08
#    Facebook_Price            155
#    Google_Price             1000
#    Microsoft_Price            61
#    Facebook_PE             36.11
#    Google_PE                31.2
#    Microsoft_PE            30.11
# ...

# %% [markdown]
# # Crosstab

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# Define the data as a list of dictionaries
data = [
    {"Name": "Kathy", "Nationality": "USA", "Sex": "Female", "Age": 23, "Handedness": "Right"},
    {"Name": "Linda", "Nationality": "USA", "Sex": "Female", "Age": 18, "Handedness": "Right"},
    {"Name": "Peter", "Nationality": "USA", "Sex": "Male", "Age": 19, "Handedness": "Right"},
    {"Name": "John", "Nationality": "USA", "Sex": "Male", "Age": 22, "Handedness": "Left"},
    {"Name": "Fatima", "Nationality": "Bangladesh", "Sex": "Female", "Age": 31, "Handedness": "Left"},
    {"Name": "Kadir", "Nationality": "Bangladesh", "Sex": "Male", "Age": 25, "Handedness": "Left"},
    {"Name": "Dhaval", "Nationality": "India", "Sex": "Male", "Age": 35, "Handedness": "Left"},
    {"Name": "Sudir", "Nationality": "India", "Sex": "Male", "Age": 31, "Handedness": "Left"},
    {"Name": "Parvir", "Nationality": "India", "Sex": "Male", "Age": 37, "Handedness": "Right"},
    {"Name": "Yan", "Nationality": "China", "Sex": "Female", "Age": 52, "Handedness": "Right"},
    {"Name": "Juan", "Nationality": "China", "Sex": "Female", "Age": 58, "Handedness": "Left"},
    {"Name": "Liang", "Nationality": "China", "Sex": "Male", "Age": 43, "Handedness": "Left"}
]

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima  Bangladesh  Female   31       Left
# 5    Kadir  Bangladesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7    Sudir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima  Bangladesh  Female   31       Left
# 5    Kadir  Bangladesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7    Sudir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(index=df['Nationality'],columns=df['Handedness'])
# Out:
# Handedness   Left  Right
# Nationality
# Bangladesh      2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(index=df['Sex'],columns=df['Handedness'])
# Out:
# Handedness  Left  Right
# Sex
# Female         2      3
# Male           5      2

# %%
pd.crosstab(index=df['Nationality'],columns=df['Handedness'],margins=True)
# Out:
# Handedness   Left  Right  All
# Nationality
# Bangladesh      2      0    2
# China           2      1    3
# India           2      1    3
# USA             1      3    4
# All             7      5   12

# %%
pd.crosstab(index=[df['Nationality'],df['Sex']],columns=df['Handedness'],margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangladesh  Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
pd.crosstab(index=df['Nationality'],columns=[df['Handedness'],df['Sex']],margins=True)
# Out:
# Handedness    Left       Right      All
# Sex         Female Male Female Male
# Nationality
# Bangladesh       1    1      0    0   2
# China            1    1      1    0   3
# India            0    2      0    1   3
# USA              0    1      2    1   4
# All              2    5      3    2  12

# %%
import numpy as np
pd.crosstab([df.Sex],[df.Handedness], values=df.Age,aggfunc=np.average)
# Out:
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# # Reading and WRiting the data from DB

# %%
import pandas as pd
import sqlalchemy

# %%
"""
engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/application')
df = pd.read_sql_table("customer",engine,columns=['name'])
query = '''
Select * from dual
'''
df = pd.read_sql_query(query,engine)
df.rename(columns = {
    "Customer Name" : "name",
    "Customer Phone" : "phone"
})
df.to_sql(
name="customers",
con=engine,
index=False,
if_exists='append'
)

pd.read_sql("customer",engine )
pd.read_sql(query,engine )

"""
# Out:
# '\nengine = sqlalchemy.create_engine(\'mysql+pymysql://root:@localhost:3306/application\')\ndf = pd.read_sql_table("customer",engine,columns=[\'name\'])\nquery = \'\'\'\nSelect * from dual \n\'\'\'\ndf = pd.read_sql_query(query,engine)\ndf.rename(columns = {\n    "Customer Name" : "name",\n    "Customer Phone" : "phone"\n})\ndf.to_sql(\nname="customers",\ncon=engine,\nindex=False,\nif_exists=\'append\'\n)\n\npd.read_sql("customer",engine )\npd.read_sql(query,engine )\n\n'

# %% [markdown]
# # How to optimize the memory
#
# 1. Dont load all the columns while importing the data from csv or table.
# 2. int8 int16, int32, int64(default). If the field is like ward number which has values from 1 to 32 then in that case int8 is enough which can save significant memory. dtype={"ward_number": "int8"}
#
# 3. Convert the categorical values into categorical data type, it will reduce the memory drastically. df = pd.read_csv("voter.csv",dtype={"Party_affiliation":"category"})
# 4. Sparse Series (dropna)
# sparse_series = series.astype("Sparse[str]")

# %% [markdown]
# # Time Series analysis in Pandas
